# %% [markdown]
# <a href="https://colab.research.google.com/github/varadvyas10/Work-in-Progress/blob/main/Titanic_DataBase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Upload the data from desktop

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb17df5f-fd4b-4c7e-b637-cef5f21a81aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb17df5f-fd4b-4c7e-b637-cef5f21a81aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import io

# %%
df =  pd.read_csv(io.BytesIO(uploaded['The_Titanic_dataset.xlsx - The Titanic dataset (1).csv']),header=1)
df.head(10)
# Out:
#    sn  pclass  survived                                Unnamed: 3  gender  \
# 0   1       3         0                               Mr. Anthony    male
# 1   1       3         0                               Mr. Anthony    male
# 2   2       3         0                     Master. Eugene Joseph    male
# 3   3       2         0               Abbott, Mr. Rossmore Edward     NaN
# 4   4       3         1               Abbott, Mr. Rossmore Edward  female
# 5   5       3         1               Abelseth, Miss. Karen Marie  female
# 6   6       3         1             Abelseth, Mr. Olaus Jorgensen    male
# 7   7       2         0                       Abelson, Mr. Samuel    male
# 8   8       2         1     Abelson, Mrs. Samuel (Hannah Wizosky)  female
# 9   9       3         1  Abrahamsson, Mr. Abraham August Johannes    male
#
#    age  family   fare embarked      date
# 0   42     0.0   7.55      NaN  1-Jan-90
# 1   42     0.0   7.55      NaN  1-Jan-90
# ...

# %%
df
# Out:
#         sn  pclass  survived                              Unnamed: 3  gender  \
# 0        1       3         0                             Mr. Anthony    male
# 1        1       3         0                             Mr. Anthony    male
# 2        2       3         0                   Master. Eugene Joseph    male
# 3        3       2         0             Abbott, Mr. Rossmore Edward     NaN
# 4        4       3         1             Abbott, Mr. Rossmore Edward  female
# ...    ...     ...       ...                                     ...     ...
# 1296  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1297  1297       3         0                    Zabour, Miss. Hileni  female
# 1298  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1299  1299       3         0                     Zakarian, Mr. Ortin    male
# 1300  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...

# %% [markdown]
# Rename the Columns

# %%
df.rename(columns={'Sr_No.': 'Srn.', 'gender': 'Sex', 'pclass': 'Passenger Class', 'Unnamed: 3': 'Passenge Name' , 'age': 'Age', 'family': 'Family Members', 'fare': 'Fare', 'embarked': 'Embarked', 'date': 'Date', 'survived': 'Survived'}, inplace=True)

# %%
df
# Out:
#       Srn.  Passenger Class  Survived                           Passenge Name  \
# 0        1                3         0                             Mr. Anthony
# 1        1                3         0                             Mr. Anthony
# 2        2                3         0                   Master. Eugene Joseph
# 3        3                2         0             Abbott, Mr. Rossmore Edward
# 4        4                3         1             Abbott, Mr. Rossmore Edward
# ...    ...              ...       ...                                     ...
# 1296  1296                2         0  Yrois, Miss. Henriette ("Mrs Harbeck")
# 1297  1297                3         0                    Zabour, Miss. Hileni
# 1298  1298                3         0               Zakarian, Mr. Mapriededer
# 1299  1299                3         0                     Zakarian, Mr. Ortin
# 1300  1300                3         0                      Zimmerman, Mr. Leo
#
# ...

# %% [markdown]
# get the Datatype of every columns

# %%
df =  pd.read_csv(io.BytesIO(uploaded['The_Titanic_dataset.xlsx - The Titanic dataset (1).csv']), encoding='UTF-8')
df =  pd.read_csv(io.BytesIO(uploaded['The_Titanic_dataset.xlsx - The Titanic dataset (1).csv'])).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       1302 non-null   object
#  1   2       1302 non-null   object
#  2   3       1302 non-null   object
#  3   4       1301 non-null   object
#  4   5       1301 non-null   object
#  5   6       1045 non-null   object
#  6   7       1300 non-null   object
#  7   8       1300 non-null   object
#  8   9       1296 non-null   object
#  9   10      1302 non-null   object
# dtypes: object(10)
# memory usage: 101.8+ KB

# %% [markdown]
# Devide entire data into small chunks

# %%
# dfs = pd.read_csv(io.BytesIO(uploaded['The_Titanic_dataset.xlsx - The Titanic dataset (1).csv']), chunksize=500)

# %%
# for chunks in dfs :
#   print(chunks.shape)

# %%
import pandas as pd
import seaborn as sns
import io

# df = pd.read_csv(io.BytesIO(uploaded['The_Titanic_dataset.xlsx - The Titanic dataset (1).csv']))
# df.info()
# print(df.columns.tolist())


# Step 3: Plot with seaborn
# sns.countplot(df['3'])
# sns.countplot(df['2'])
df['2'].value_counts().plot(kind='pie' , autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Male : Female = 64.18 : 35.74**

# %%
df['5'].value_counts().plot(kind='pie' , autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
import pandas as pd

col = pd.to_numeric(df['6'], errors='coerce').dropna()
plt.hist(col, bins=10)
plt.title('Histogram of Column Age')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Died : Survived = 61.52 : 38.40**

# %%
df['3'].value_counts().plot(kind='pie' , autopct='%.2f')
# Out:
# <Axes: ylabel='count'>
